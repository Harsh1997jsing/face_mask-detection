# %%
import numpy as np

# %%
import cv2
   
from keras.models import load_model

# %%
model =load_model("cnn.h5")

# %%
def draw_label(img,text,pos,bg_color):
    text_size = cv2.getTextSize(text,cv2.FONT_HERSHEY_SIMPLEX,1,2)
    
    end_x = pos[0] + text_size[0][0] + 2
    end_y = pos[1] + text_size[0][1] - 2
    
    cv2.rectangle(img,pos,(end_x,end_y),bg_color)
    cv2.putText(img,text,pos,cv2.FONT_HERSHEY_SIMPLEX,1,(0,0,0),1,cv2.LINE_AA)

# %%
def detect_face_mask(img):
    y_pred = model.predict(img.reshape(1,128,128,3))
    classes = np.argmax(y_pred,axis=1)
    return classes[0]

# %%
cap = cv2.VideoCapture(0)
while True:
    ret, frame = cap.read()
    img = cv2.resize(frame,(128,128))
    y_pred = detect_face_mask(img)
    
    
    if y_pred ==0:
        draw_label(frame,"Mask",(30,30),(0,255,0))
    else:
        draw_label(frame,"No Mask",(30,30),(0,0,255))
    print(y_pred)
    cv2.imshow("window",frame)
    if cv2.waitKey(1) & 0xff == ord('x'):
        break
cv2.destroyAllWindows()
# Out:
# 1/1 [==============================] - 0s 49ms/step
# 1
# 1/1 [==============================] - 0s 65ms/step
# 1
# 1/1 [==============================] - 0s 48ms/step
# 1
# 1/1 [==============================] - 0s 46ms/step
# 1
# 1/1 [==============================] - 0s 48ms/step
# 1
# 1/1 [==============================] - 0s 48ms/step
# 1
# 1/1 [==============================] - 0s 56ms/step
# 1
# 1/1 [==============================] - 0s 55ms/step
# 1
# 1/1 [==============================] - 0s 53ms/step
# 1
# 1/1 [==============================] - 0s 50ms/step
# 1
# 1/1 [==============================] - 0s 51ms/step
# 1
# 1/1 [==============================] - 0s 50ms/step
# 1
# 1/1 [==============================] - 0s 50ms/step
# 1
# 1/1 [==============================] - 0s 49ms/step
# 1
# 1/1 [==============================] - 0s 52ms/step
# 1
# 1/1 [==============================] - 0s 57ms/step
# 1
# 1/1 [==============================] - 0s 53ms/step
# 1
# ...

# %%
sample = cv2.imread(r"D:\cnn\data\with_mask\with_mask_2.jpg")
sample = cv2.resize(sample,(128,128))

# %%
detect_face_mask(sample)
# Out:
# 1/1 [==============================] - 0s 49ms/step
# 0
